# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

import requests
import json
URL="https://www.dcard.tw/_api/forums/pet/posts?popular=true"
re=requests.get(URL)
r=re.text
data = json.loads(r)
print(len(data))
print(data[0].keys())
# Out:
# 30
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」


import requests
import json
URL="https://www.dcard.tw/_api/forums/pet/posts?popular=true"
re=requests.get(URL)
r=re.text
data = json.loads(r)
data_title=[]
data_createdAt=[]
data_commentCount=[]
data_likeCount=[]
for i in range(len(data)):
    data_title.append(data[i]['title'])
    data_createdAt.append(data[i]['createdAt'])
    data_commentCount.append(data[i]['commentCount'])
    data_likeCount.append(data[i]['likeCount'])
print(data_title)
print(data_createdAt)
print(data_commentCount)
print(data_likeCount)
# Out:
# ['你是要我睡哪裡', '投降的貓咪', '養貓的看到真的有感', '#貓 是俊榮！！', '同學你的貓也太霸氣了吧！', '你們有看到我的兔兔嗎？#圖多', '厭世的卡納胖拉', '你其實是兔子吧', '蓋個瑪爾濟一、濟二、濟三、瑪爾濟斯樓', '打哈欠', '請給媽媽一點個人空間', '我家也有狐獴啦😳', '你的貓太可愛啦！！！', '#圖 媽 所以我的哥哥勒？', '小貓 vs 哈士奇の貓狗大戰', '一點點溫暖', '看鏡頭柴', '我是yoyo施米達🐾', '到底誰才是正宮！', '小南門被棄養的狗', '#更  真的是傲嬌黏人貓', '協尋我家狗狗😭', '這位同學你的貓被通緝了', '金鋼狼出現了！', '每天都想吸貓 我家的貓真的可愛到融化😭😭🥺🥺', '只是想曬貓', '看到這麼可愛的貓貓還不還錢嗎？', '寵物溝通 求助', '台中公益路上#走失#吉娃娃', '發現被母貓遺棄的奶貓']
# ['2019-12-05T05:31:34.760Z', '2019-12-05T15:38:46.127Z', '2019-12-05T16:58:51.962Z', '2019-12-05T07:58:20.451Z', '2019-12-05T14:31:08.763Z', '2019-12-05T06:49:33.372Z', '2019-12-05T06:37:47.406Z', '2019-12-05T13:34:47.878Z', '2019-12-05T05:06:06.855Z', '2019-12-05T10:51:05.471Z', '2019-12-05T12:07:04.022Z', '2019-12-05T15:11:33.392Z', '2019-12-05T10:05:57.375Z', '2019-12-06T10:36:45.348Z', '2019-12-06T05:59:13.675Z', '2019-12-05T15:07:30.954Z', '2019-12-05T13:08:14.274Z', '2019-12-05T08:52:33.871Z', '2019-12-06T06:27:08.672Z', '2019-12-05T17:12:38.037Z', '2019-12-05T14:06:14.948Z', '2019-12-05T07:24:27.979Z', '2019-12-06T00:36:50.915Z', '2019-12-06T06:54:49.757Z', '2019-12-05T15:02:18.430Z', '2019-12-06T09:03:54.724Z', '2019-12-05T16:36:17.447Z', '2019-12-05T18:09:02.478Z', '2019-12-05T12:59:39.165Z', '2019-12-06T06:59:54.426Z']
# [67, 16, 11, 14, 9, 18, 9, 4, 51, 3, 1, 6, 2, 5, 1, 8, 0, 0, 0, 0, 6, 0, 6, 0, 8, 8, 1, 6, 0, 7]
# [2467, 976, 582, 498, 465, 369, 251, 98, 94, 68, 52, 39, 36, 31, 29, 29, 25, 23, 21, 21, 21, 18, 17, 16, 16, 15, 14, 13, 13, 12]

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

import requests
import json
URL="https://www.dcard.tw/_api/forums/pet/posts?popular=true"
re=requests.get(URL)
r=re.text
data = json.loads(r)
c=int(len(data))
dac=0
dal=0
for i in range(c):
    dac+=data[i]['commentCount']
    dal+=data[i]['likeCount']
print(data)
print(dal/c)
# Out:
# [{'id': 232629154, 'title': '你是要我睡哪裡', 'excerpt': '每次都要躺我的枕頭，你到底是什麼意思，是要我改天去貓砂盆上廁所嗎', 'anonymousSchool': False, 'anonymousDepartment': True, 'pinned': False, 'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49', 'replyId': None, 'createdAt': '2019-12-05T05:31:34.760Z', 'updatedAt': '2019-12-05T05:31:34.760Z', 'commentCount': 67, 'likeCount': 2467, 'withNickname': False, 'tags': [], 'topics': ['貓'], 'meta': {'layout': 'classic'}, 'forumName': '寵物', 'forumAlias': 'pet', 'gender': 'M', 'school': '台北海洋科技大學', 'replyTitle': None, 'mediaMeta': [], 'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 2405}, {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 60}, {'id': '4b018f48-e184-445f-adf1-fc8e04ba09b9', 'count': 2}], 'hidden': False, 'customStyle': None, 'isSuspiciousAccount': False, 'layout': 'classic', 'withImages': True, 'withVideos': False, 'media': [{'url': 'https://i.imgur.com/ZHWsfbD.jpg'}, {'url': 'https://i.imgur.com/39tEUeL.jpg'}], 'reportReasonText': '', 'postAvatar': ''}, {'id': 232632566, 'title': '投降的貓咪', 'excerpt': '這兩天下雨覺得流浪貓們很可憐，就用紙箱弄的一個小窩給他們住，結果今天一個畫面直接讓我笑歪，就不多說了直接上圖，這隻虎背熊腰的貓，直接 I surrender，我投降', 'anonymousSchool': False, 'anonymousDepartment': True, 'pinned': False, 'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49', 'replyId': None, 'createdAt': '2019-12-05T15:38:46.127Z', 'updatedAt': '2019-12-05T15:38:46.127Z', 'commentCount': 16, 'likeCount': 976, 'withNickname': False, 'tags': [], 'topics': ['貓咪', '貓', '寵物', '米克斯', '可愛'], 'meta': {'layout': 'classic'}, 'forumName': '寵物', 'forumAlias': 'pet', 'gender': 'F', 'school': '里茲大學', 'replyTitle': None, 'mediaMeta': [], 'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 949}, {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 25}, {'id': '4b018f48-e184-445f-adf1-fc8e04ba09b9', 'count': 1}, {'id': '514c2569-fd53-4d9d-a415-bf0f88e7329f', 'count': 1}], 'hidden': False, 'customStyle': None, 'isSuspiciousAccount': False, 'layout': 'classic', 'withImages': True, 'withVideos': False, 'media': [{'url': 'https://i.imgur.com/AWpqf8S.jpg'}, {'url': 'https://i.imgur.com/qd1n4YS.jpg'}], 'reportReasonText': '', 'postAvatar': ''}, {'id': 232633125, 'title': '養貓的看到真的有感', 'excerpt': '我們家憨吉也越來越肥了，逐漸邁入肥宅，目前4.7公斤，但白色顯胖，從小時候開始，要生氣一輩子的憨吉，3個月大，5個月大，6個月蛋蛋消失，8個月大懷疑貓生，1歲玩躲貓貓，如今過完2歲生日，看人都用下巴看', 'anonymousSchool': False, 'anonymousDepartment': False, 'pinned': False, 'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49', 'replyId': None, 'createdAt': '2019-12-05T16:58:51.962Z', 'updatedAt': '2019-12-05T16:59:51.763Z', 'commentCount': 11, 'likeCount': 582, 'withNickname': True, 'tags': [], 'topics': ['貓'], 'meta': {'layout': 'classic'}, 'forumName': '寵物', 'forumAlias': 'pet', 'gender': 'M', 'school': '延平北路最會養貓的男人', 'department': 'me5168', 'replyTitle': None, 'mediaMeta': [], 'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 570}, {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 12}], 'hidden': False, 'customStyle': None, 'isSuspiciousAccount': False, 'layout': 'classic', 'withImages': True, 'withVideos': False, 'media': [{'url': 'https://i.imgur.com/tYZUYsP.jpg'}, {'url': 'https://i.imgur.com/FmuGcHs.jpg'}, {'url': 'https://i.imgur.com/vUStrBN.jpg'}, {'url': 'https://i.imgur.com/1Ju6G2L.jpg'}, {'url': 'https://i.imgur.com/QjzjMoN.jpg'}, {'url': 'https://i.imgur.com/IOGPHT6.jpg'}, {'url': 'https://i.imgur.com/uiPIMbH.jpg'}, {'url': 'https://i.imgur.com/2ndzMVE.jpg'}, {'url': 'https://i.imgur.com/qiCdAvr.jpg'}, {'url': 'https://i.imgur.com/3csWWwD.jpg'}], 'reportReasonText': '', 'postAvatar': ''}, {'id': 232629838, 'title': '#貓 是俊榮！！', 'excerpt': '不曉得各位有沒有關注豆漿的IG呢，上面常常有娘娘的奇蹟美照，然後就在剛才！！，限時動態中出現了一隻小貓仔！！，是俊榮啊！！，雖然漿爸還沒有正式宣布小貓的名字，但漿絲們幾乎都已認定了他叫俊榮，（俊榮出處', 'anonymousSchool': False, 'anonymousDepartment': True, 'pinned': False, 'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49', 'replyId': None, 'createdAt': '2019-12-05T07:58:20.451Z', 'updatedAt': '2019-12-06T09:09:21.172Z', 'commentCount': 14, 'likeCount': 498, 'withNickname': False, 'tags' ...
# 210.96666666666667
